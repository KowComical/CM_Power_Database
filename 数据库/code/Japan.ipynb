# %%
import pandas as pd

# %%
file_path = 'D:\\Python\\Work\\朱碧青\\Code_Store\\数据库\\data\\asia\\japan\\raw\\'
df = pd.read_csv(file_path+'202112_10エリア計.csv', encoding = 'Shift_JIS', header = 3)
df_occto = pd.read_csv(file_path+'occto.csv')

# %%
df[df.duplicated()]
# Out:
#              月日   時刻        需要   原子力   地熱      水力       火力   バイオマス    風力実績  \
# 0     2021/12/1   0時   86199.2  7336  293  5460.9  74090.5  1624.2  2604.6
# 1     2021/12/1   1時   84744.4  7337  293  5578.9  73207.3  1619.2  2549.0
# 2     2021/12/1   2時   86753.1  7337  294  5899.9  74449.1  1622.2  2545.9
# 3     2021/12/1   3時   89167.5  7338  293  6207.9  75468.9  1625.2  2599.5
# 4     2021/12/1   4時   90559.2  7335  294  6699.9  75352.6  1613.2  2700.5
# ..          ...  ...       ...   ...  ...     ...      ...     ...     ...
# 739  2021/12/31  19時  115436.5  9136  314  7511.9  91125.2  1691.2  2574.2
# 740  2021/12/31  20時  113229.3  9133  311  6650.9  90381.6  1693.2  2529.6
# 741  2021/12/31  21時  110404.6  9135  313  5797.9  88908.1  1692.2  2567.4
# 742  2021/12/31  22時  106658.3  9137  314  4986.9  87174.6  1680.2  2542.6
# 743  2021/12/31  23時  107264.7  9136  313  4785.9  87462.7  1684.2  2506.9
#
#      風力抑制量  太陽光実績  太陽光抑制量    揚水
# 0        0    0.0       0 -5392
# ...
